# %%
import numpy as np
import pandas as pd
import math as m
from statsmodels.tsa.stattools import acf
from statsmodels.graphics.tsaplots import plot_acf
from scipy import *
import scipy.linalg
import torch
from torch import nn, optim
import mpl_toolkits.mplot3d.axes3d as p3
from sklearn.datasets import make_swiss_roll
from sklearn.preprocessing import MinMaxScaler


import scaleogram as scg
import matplotlib.pyplot as plt
import warnings

from visuals import *
from my_lib import *
from SSA_lib import SSA

# %%
warnings.simplefilter('ignore')

plt.rcParams['figure.figsize'] = 10, 10
plt.rcParams['font.family'] = 'DejaVu Serif'
plt.rcParams['lines.linewidth'] = 2
plt.rcParams['lines.markersize'] = 8
plt.rcParams['xtick.labelsize'] = 16
plt.rcParams['ytick.labelsize'] = 16
plt.rcParams['legend.fontsize'] = 16
plt.rcParams['axes.titlesize'] = 24
plt.rcParams['axes.labelsize'] = 8

# %%
device = ('cuda' if torch.cuda.is_available() else 'cpu')

# %%
dt = 459*10
#data = pd.read_csv('data/long_walk_100_acc.csv', delimiter =';', decimal=',')[3815+6*455:3815+6*455+dt]
data = pd.read_csv('data/long_walk_100_acc.csv', delimiter =';', decimal=',')[7009:7009+dt]
#data = pd.read_csv('data/long_walk_100_acc.csv', delimiter =';', decimal=',')[3785:8000]
#data = pd.read_csv('data/home_lin_10_lac.csv', delimiter =';', decimal=',')[:]
frecuency = len(data)/(data['time'].values[-1]-data['time'].values[0])
assert 480 < frecuency < 520

x_acc = ( (data['X_value'].values)**2 + (data['Y_value'].values)**2 + (data['Z_value'].values)**2)**.5
_m = np.mean(x_acc)
x_acc -= _m
t = (data['time'].values).astype(float).reshape([-1,])
t = np.linspace(0,t[-1]-t[0],len(x_acc))

fig = go.Figure()
fig.add_scatter(y = x_acc, mode='lines', name='Sum squares')
fig.show()
# Out:
# <div>
#
#
#             <div id="6f85895e-6ea7-4dc9-8fb7-ce85895a1a8d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6f85895e-6ea7-4dc9-8fb7-ce85895a1a8d")) {
#                     Plotly.newPlot(
#                         '6f85895e-6ea7-4dc9-8fb7-ce85895a1a8d',
#                         [{"mode": "lines", "name": "Sum squares", "type": "scatter", "y": [0.981429231932097, 1.0392496990745368, 1.3148517076173842, 1.5697733865244405, 2.22250569250947, 2.9350265598245127, 3.2732835108453777, 3.8624460599357704, 4.2862929571579365, 4.739399606322706, 4.565441311056629, 4.860492870040062, 5.126745264111744, 5.4889777385440315, 5.690840536270963, 6.126990790367207, 6.559103568861458, 6.748965584951327, 7.15622749205682, 7.725398967781169, 7.725398967781169, 7.799832431770115, 7.8763804165400675, 7.992043415188599, 8.025971960381272, 8.036081369218705, 8.058156651500509, 8.043458893996744, 7.986554105724567, 7.495099763530066, 7.495099763530066, 7.325163315691141, 7.024933586120751, 6.883884625071149, 6.618491961827791, 6.369923774805011, 6.234155299763609, 6.047314932702557, 6.003729832177017, 5.867701874852331, 5.867701874852331, 5.810307122794898, 5.649521713752025, 5.473434927956122, 5.378951921006026, 5.233390887322203, 5.145480205860059, 4.894842211479114, 4.525576323160099, 3.918452798
865747104668515, 32.611740707112546, 29.34006977527377, 26.05417962139764, 22.757493254191576, 19.453402295295003, 16.145258470862967, 12.836366685760526, 9.529979743837412, 6.229294880325791, 2.9374507185127956, -0.3424744965346639, -3.607461459863727, -6.854549830777142, -10.080835681379572, -13.283467866207607, -16.459646483477062, -19.60661738313642, -22.721669328066564, -25.80213124740187, -28.84536674420645, -31.84877334273505, -34.809778162976315, -37.72583959914816, -40.594447708946454, -43.413125152335205, -46.17943142157002, -48.89096891847658, -51.545387885264, -54.140396657792664, -56.67377040172224, -59.14336100493028, -61.547112458375906, -63.883065486227295, -66.14936935984653, -68.34429367252174, -70.46623831018873, -72.51374442228007, -74.48550128103393, -76.38035160086704, -78.19729675328554, -79.93549772916421, -81.59427640225499, -83.17310796427374, -84.6716165625493, -86.08956826206503, -87.42686195231097, -88.68351633428016, -89.85965976257864, -90.95551553601517, -91.97138451806168, -92.90763204962066, -93.76467327580228, -94.5429544398791, -95.24293806636315, -95.86508950208075, -96.40986571740922, -96.87770393403693, -97.269 ...

# %%
X = HankelMatrix(x_acc_clear,600)
x = torch.from_numpy(X).to(device)

# %%
class Autoencoder(nn.Module):
    """Makes the main denoising auto

    Parameters
    ----------
    in_shape [int] : input shape
    enc_shape [int] : desired encoded shape
    """

    def __init__(self, in_shape, enc_shape):
        super(Autoencoder, self).__init__()
        
        self.encode = nn.Sequential(
            nn.Linear(in_shape, 512),
            nn.ReLU(True),
            nn.Dropout(0.2),
            
            nn.Linear(512, 256),
            nn.ReLU(True),
            nn.Dropout(0.2),
            
            nn.Linear(256, 128),
            nn.ReLU(True),
            nn.Dropout(0.2),
            
            nn.Linear(128, 64),
            nn.ReLU(True),
            nn.Dropout(0.2),
            
            nn.Linear(64, enc_shape),
        )
        
        self.decode = nn.Sequential(
            nn.Linear(enc_shape, 64),
            nn.ReLU(True),
            nn.Dropout(0.2),
            
            nn.Linear(64, 128),
            nn.ReLU(True),
            nn.Dropout(0.2),
            
            nn.Linear(128, 256),
            nn.ReLU(True),
            nn.Dropout(0.2),
            
            nn.Linear(256, 512),
            nn.ReLU(True),
            nn.Dropout(0.2),
            
            nn.Linear(512, in_shape)
        )
        
    def forward(self, x):
        x = self.encode(x)
        x = self.decode(x)
        return x

# %%
encoder = Autoencoder(in_shape=600, enc_shape=3).double().to(device)

error = nn.MSELoss()

optimizer = optim.Adam(encoder.parameters())

def train(model, error, optimizer, n_epochs, x):
    model.train()
    for epoch in range(1, n_epochs + 1):
        optimizer.zero_grad()
        output = model(x)
        loss = error(output, x)
        loss.backward()
        optimizer.step()
        
        if epoch % int(0.1*n_epochs) == 0:
            print(f'epoch {epoch} \t Loss: {loss.item():.4g}')

# %%
train(encoder, error, optimizer, 100, x)
# Out:
# epoch 10 	 Loss: 0.714
# epoch 20 	 Loss: 0.7098
# epoch 30 	 Loss: 0.6886
# epoch 40 	 Loss: 0.6857
# epoch 50 	 Loss: 0.6743
# epoch 60 	 Loss: 0.6641
# epoch 70 	 Loss: 0.6542
# epoch 80 	 Loss: 0.6314
# epoch 90 	 Loss: 0.6362
# epoch 100 	 Loss: 0.6173

# %%
with torch.no_grad():
    encoded = encoder.encode(x)
    decoded = encoder.decode(encoded)
    mse = error(decoded, x).item()
    enc = encoded.cpu().detach().numpy()
    dec = decoded.cpu().detach().numpy()

# %%
fig_2 = go.Figure()


fig_2.add_trace(go.Scatter3d(x=enc[:1000,0][::],
                             y=enc[:1000,1][::],
                             z=enc[:1000,2][::],
                             #mode='markers',
                             marker=dict(
                                         size=0.1,
                                         line=dict(
                                                    width=0.01
                                                  )

                                         ),
                             name='trajectory'
                            )
                )


fig_2.layout.template = 'plotly_white'
fig_2.show()
# Out:
# <div>
#
#
#             <div id="0b3ef1ff-4a13-4243-8108-a5e32426474a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0b3ef1ff-4a13-4243-8108-a5e32426474a")) {
#                     Plotly.newPlot(
#                         '0b3ef1ff-4a13-4243-8108-a5e32426474a',
#                         [{"marker": {"line": {"width": 0.01}, "size": 0.1}, "name": "trajectory", "type": "scatter3d", "x": [2.4484367146886887, 1.3740496637737374, 1.7318536864350274, 1.7076739868221134, -0.2739645070513734, 0.6707607200945543, 0.6467519889488494, -0.24164843676289632, -1.3384836537997404, -1.4224188191180378, -1.299799157235317, -1.020513118599842, -2.3915836094268728, -2.069744335858579, -1.3533292597208533, -1.2357397754629145, -4.361281572470192, -2.502632276325873, -1.99252156210038, -4.443524995529196, -3.6087797972273954, -2.924670695968322, -2.1488370374552725, -4.445808595731197, -3.2298497843103164, -2.7867878456706725, -3.4228249635588983, -4.015262494934207, -3.2437889778230793, -4.026811322633344, -5.383396629028404, -3.8790632216957692, -4.82537206672434, -4.29522001866044, -5.296209146940481, -4.490464867706981, -6.155437098190921, -5.81704670403922, -4.856676096542957, -6.439191441248915, -4.974339982664434, -4.516048481099402, -6.39037746165863, -6.215443837338833, -5.356198205281797, -5.17711839182318, -4.435329621662113, -6.1465496117035485, -5.345311625560502, -4.772829963473153, -5.264136030229159, -6.88440530051693, -5.785493737443208, -5.399102345433177, -6.416111575807774, -6.284874892693272, -8.103781599825304, -5.725202720082221, -8.538223761679763, -5.96798161414666, -8.164635312697799, -7.632921649408227, -6.871316139254791, -6.457532730439866, -7.872236244447081, -4.123200050448031, -10.393145468729315, -6.381517426388191, -7.535205183825222, -9.192175040252732, -7.611726914064463, -5.270495331184973, -8.186805432636385, -7.673381585625686, -4.776063605504162, -5.540947459876429, -5.444838322805238, -6.289435718632866, -7.345426706268559, -8.985807155603974, -6.181513227874637, -6.7936788442995075, -7.101792746557542, -8.181397312962229, -4.799699209632931, -6.6246131093555185, -4.4766349656971025, -5.033653902869013, -7.0953630957158635, -5.084320979769815, -6.990030173558343, -7.114836033617835, -5.404788794457914, -4.532716944953869, -2.9886737780493418, -7.0897229696533435, -3.847063750807214, -4.613143735376147, -2.9250225720385314, 0.5553760887488512, -4.228311276434295, -2.272537446722612, -3.173143309992887, -2.634024021185168, -3.008215241666295, -1.8333580670194665, 0.496204702661841, -0.2863518311945825, 0.12871041954188, -0.601169345351782, 1.396364322511367, 0.3001433641488905, 2.358216074626909, 3.21554501583993, 3.204465536171938, 5.633087353593752, 4.184357049023874, 5.942979139625792, 8.935599455873916, 5.445695845698402, 6.694114944892037, 5.4243717303756585, 5.4024005328612645, 4.953056917335221, 8.242466386700759, 7.227515134468197, 7.9651519325161395, 5.912181811890102, 7.467397495339492, 9.86696980821355, 6.132340816997917, 7.139024570431082, 9.034647619251396, 8.675006527235377, 9.684267934584264, 11.800512335660185, 8.000805625706304, 12.096986412050772, 10.652807292992817, 6.34640627123933, 10.567595599523376, 8.655778161729415, 11.201092878566733, 5.79066548835477, 9.957258800612289, 10.260620037511927, 11.937876615492497, 12.385951881552185, 10.06489310808494, 8.919090715098454, 11.891915155332763, 9.966837854973825, 8.654012144889727, 14.714272105301331, 13.253487053811007, 11.730236481968934, 8.958596844847762, 8.738462834021057, 10.664322760292082, 13.031239808629602, 9.040047897186533, 10.694219973657063, 8.204404812274168, 11.266783537657945, 9.015547932747278, 13.674549669199704, 15.374779157966335, 12.073160498249434, 12.809207088503287, 11.965675110711766, 8.999422317476299, 14.38430320956337, 14.532358942007829, 11.683140079793446, 9.83119753073118, 12.158467356113603, 7.899987718545864, 7.691130411844766, 10.67491202549036, 12.116348568812326, 9.154520478126482, 8.635231412827588, 7.910915275118831, 8.206304001870274, 7.332589100996093, 7.164498560554878, 8.274831742430191, 5.579945681754698, 4.237543905201106, 5.547891278577417, 7.378256877515273, 6.008038942872962, 5.760168508269204, 3.9963858601949527, 3.332455698080383, 2.795940868150066, 6 ...

# %%
T = np.array([
            [1,0,0],
            [0,np.cos(a),-np.sin(a)],
            [0,np.sin(a),np.cos(a)]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-7c3cc0446d5f> in <module>
#       1 T = np.array([
#       2             [1,0,0],
# ----> 3             [0,np.cos(a),-np.sin(a)],
#       4             [0,np.sin(a),np.cos(a)]])
#
# NameError: name 'a' is not defined

# %%
enc_T = enc@T

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(enc_T[:1000,0], enc_T[:1000,1], enc_T[:1000,2])

ax.xaxis.set_rotate_label(False)
ax.yaxis.set_rotate_label(False)
ax.zaxis.set_rotate_label(False)
#ax.set_zlim(contourz,X_PCA[:,2].max()*1.1)
ax.view_init(elev=20, azim=-120)

ax.grid(False)
ax.xaxis.pane.set_edgecolor('black')
ax.yaxis.pane.set_edgecolor('black')
ax.xaxis.pane.fill = False
ax.yaxis.pane.fill = False
ax.zaxis.pane.fill = False

fig.savefig('/Users/denistikhonov/Desktop/Study/IAD'
            +'/Research_work/Spherical_Harmonics_parametrisation/doc/figs/phase_enc.eps',
            format='eps',
            dpi=600)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
Sphere_projection(enc, n = 1)
# Out:
# <div>
#
#
#             <div id="a5944486-4efd-4562-ba3c-139de4874541" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a5944486-4efd-4562-ba3c-139de4874541")) {
#                     Plotly.newPlot(
#                         'a5944486-4efd-4562-ba3c-139de4874541',
#                         [{"showscale": false, "surfacecolor": [[0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98], [0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213, 0.9795066115355213], [0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429424467, 0.9780269429 ...
