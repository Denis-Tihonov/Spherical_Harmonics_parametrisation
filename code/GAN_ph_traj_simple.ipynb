# %%
import numpy as np
import pandas as pd
import math as m
from statsmodels.tsa.stattools import acf
from statsmodels.graphics.tsaplots import plot_acf
# from scipy import *
import scipy.linalg
from scipy.optimize import minimize
from scipy.linalg import eig, eigh
from scipy.fft import fft

from sklearn.datasets import make_swiss_roll
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import kneighbors_graph, NearestNeighbors
from sklearn.decomposition import KernelPCA, PCA
from sklearn.manifold import TSNE
from sklearn.metrics import mean_squared_error
from sklearn.neighbors import NearestNeighbors

#import scaleogram as scg
import matplotlib.pyplot as plt
import warnings

from visuals import *
from my_lib import *
from SSA_lib import SSA

# %%
warnings.simplefilter('ignore')

# plt.rcParams['text.usetex'] = True
plt.rcParams['figure.figsize'] = 5, 5
plt.rcParams['font.family'] = 'DejaVu Serif'
plt.rcParams['lines.linewidth'] = 2
plt.rcParams['lines.markersize'] = 8
plt.rcParams['xtick.labelsize'] = 16
plt.rcParams['ytick.labelsize'] = 16
plt.rcParams['legend.fontsize'] = 16
plt.rcParams['axes.titlesize'] = 24
plt.rcParams['axes.labelsize'] = 8

# %%
def CartesianToSpherical(point):
    r = np.sqrt(sum(point ** 2))
    n = len(point)
    phi = np.zeros(n - 1)
    
    for i in range(n - 2):
        phi[i] = np.arccos(point[i] / np.sqrt(sum(point[i:] ** 2)))
        
    if point[-1] >= 0:
        phi[n - 2] = np.arccos(point[n - 2] / np.sqrt(point[n - 1] ** 2 + point[n - 2] ** 2))
    else:
        phi[n - 2] = 2 * np.pi - np.arccos(point[n - 2] / np.sqrt(point[n - 1] ** 2 + point[n - 2] ** 2))
        
    return np.hstack((phi, r))


def TrajectoryToSpherical(tr):
    tr_spherical = np.zeros(tr.shape)
    for i, point in enumerate(tr):
        tr_spherical[i] = CartesianToSpherical(point)
    return tr_spherical


def SphericalToCartesian(point):
    phi, r = point[:-1], point[-1]
    n = len(point)
    x = np.zeros(n) 
    cur = r
    
    for i in range(n - 1):
        x[i] = cur * np.cos(phi[i])
        cur *= np.sin(phi[i])

    x[n - 1] = cur
    return x
    

def TrajectoryToCartesian(tr):
    tr_cartesian = np.zeros(tr.shape)
    for i, point in enumerate(tr):
        tr_cartesian[i] = SphericalToCartesian(point)
    return tr_cartesian

# %%
dt = 450 * 10
data = pd.read_csv('data/long_walk_100_acc.csv', delimiter =';', decimal=',')[7007-470*2:7007+dt]

frequency = len(data)/(data['time'].values[-1]-data['time'].values[0])

assert 490 < frequency < 510, f'Bad frequency {frequency}'
print(f'Frequency {frequency}')

x_acc = ( (data['X_value'].values)**2 + (data['Y_value'].values)**2 + (data['Z_value'].values)**2)**.5
_m = np.mean(x_acc)
_std = (sum((x_acc - _m)**2)/len(x_acc))**.5

x_acc = (x_acc-_m)

t = (data['time'].values).astype(float).reshape([-1,])
t = np.linspace(0,t[-1]-t[0],len(x_acc))

fig = go.Figure()
fig.add_scatter(y = x_acc, mode='lines', name='Sum squares')
fig.show()
# Out:
# Frequency 500.15629884338847
# <div>                            <div id="63aafb47-eb60-4b3c-a81b-fa2395af3e8e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
806355, -7.081501324141372, -7.081501324141372, -7.201558218587468, -7.314006050007766, -7.542538536878, -7.799597113662042, -7.916656977972215, -8.112085044034417, -8.240489562468229, -8.279612669650213, -8.281052980715966, -8.281052980715966, -8.273878637365707, -8.34240452700823, -8.37096643877962, -8.411664375772656, -8.46644340707052, -8.490980852090185, -8.611359523793928, -8.70976246445611, -8.843740303040928, -8.843740303040928, -8.90383448094716, -9.000263627120244, -9.096269395159391, -9.134093872646673, -9.197484804926887, -9.158468100461672, -9.115328666315632, -8.974547331373675, -8.47681507485160 ...

# %%
Fs = 500

N = len(x_acc)

__Abs = 2.0/N * np.abs(fft(x_acc)[0:N//2])

__FS = np.linspace(0.0, 1.0/2.0*Fs, N//2)

# plotting the spectrum
fig = go.Figure()
fig.add_scatter(x = __FS[0:60],
                y = __Abs[0:60],
                mode='lines',
                name='Magnitude'
               )

temp_fft = fft(x_acc)[0:N//2]

__Ph = np.arctan2(np.imag(temp_fft),np.real(temp_fft))

fig.add_scatter(x = __FS[0:60],
                y = __Ph[0:60],
                mode='markers',
                name='Phase'
               )

fig.add_trace(go.Bar(x= __FS[0:60],
                     y= __Ph[0:60],
                        #mode='markers',
                        name='Phase'
                    )
             )


fig['layout']['yaxis1'].update(title='Magnitude')
fig['layout']['xaxis1'].update(title='Frec[1/s]')
fig.show()
# Out:
# <div>                            <div id="3f5ac70b-3f0d-494d-8c59-61806603ce37" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f5ac70b-3f0d-494d-8c59-61806603ce37")) {                    Plotly.newPlot(                        "3f5ac70b-3f0d-494d-8c59-61806603ce37",                        [{"mode": "lines", "name": "Magnitude", "type": "scatter", "x": [0.0, 0.09194556822361162, 0.18389113644722324, 0.2758367046708349, 0.3677822728944465, 0.4597278411180581, 0.5516734093416698, 0.6436189775652813, 0.735564545788893, 0.8275101140125046, 0.9194556822361162, 1.0114012504597278, 1.1033468186833395, 1.1952923869069512, 1.2872379551305626, 1.3791835233541743, 1.471129091577786, 1.5630746598013976, 1.6550202280250093, 1.7469657962486207, 1.8389113644722324, 1.930856932695844, 2.0228025009194557, 2.1147480691430673, 2.206693637366679, 2.2986392055902907, 2.3905847738139023, 2.4825303420375135, 2.574475910261125, 2.666421478484737, 2.7583670467083485, 2.85031261493196, 2.942258183155572, 3.0342037513791835, 3.126149319602795, 3.218094887826407, 3.3100404560500185, 3.40198602427363, 3.4939315924972414, 3.585877160720853, 3.6778227289444647, 3.7697682971680764, 3.861713865391688, 3.9536594336152997, 4.045605001838911, 4.137550570062523, 4.229496138286135, 4.321441706509746, 4.413387274733358, 4.505332842956969, 4.597278411180581, 4.6892239794041926, 4.781169547627805, 4.873115115851416, 4.965060684075027, 5.057006252298639, 5.14895182052225, 5.2408973887458625, 5.332842956969474, 5.424788525193086], "y": [4.87518522283929e-16, 0.10162365712375793, 0.03756699561846895, 0.03478298387057531, 0.04380830749903174, 0.016612056525575025, 0.04833754041852566, 0.06116919192412424, 0.05939108164108957, 0.12347812325407148, 0.06676260470296932, 0.047476193310114274, 0.22044999269953042, 0.06144404253001546, 0.0775235090858748, 0.040727209563548875, 0.09776342942937251, 0.1308715619071649, 0.2526030198841174, 0.21320186114771075, 0.25344616186872565, 0.43212665777441867, 0.8137226070182525, 1.9747823058132536, 4.471724350807744, 1.276462142683834, 0.5686021900845291, 0.6023315227825223, 0.4696873214447659, 0.3828015469153547, 0.46116753326009535, 0.40930246914066937, 0.47273018064940386, 0.5194304481288846, 0.9582903277355719, 1.9485334682763606, 1.7881923152934787, 0.5794765590414613, 0.203317948461654, 0.30202802251797567, 0.1870007438695242, 0.12087374129666004, 0.11993107961286542, 0.08474927587446841, 0.1657909652404665, 0.29813045233042956, 0.39513114630375823, 1.0670334910486339, 0.40260358927618883, 0.1792715818146387, 0.09931800955896442, 0.15947554190804258, 0.1385134430881544, 0.13443062915381773, 0.17749951543378206, 0.05999508662463942, 0.05358198619171332, 0.06538317222621529, 0.23873868425131853, 0.8169965524258969]}, {"mode": "markers", "name": "Phase", "type": "scatter", "x": [0.0, 0.09194556822361162, 0.18389113644722324, 0.2758367046708349, 0.3677822728944465, 0.4597278411180581, 0.5516734093416698, 0.6436189775652813, 0.735564545788893, 0.8275101140125046, 0.9194556822361162, 1.0114012504597278, 1.1033468186833395, 1.1952923869069512, 1.2872379551305626, 1.3791835233541743, 1.471129091577786, 1.5630746598013976, 1.6550202280250093, 1.7469657962486207, 1.8389113644722324, 1.930856932695844, 2.0228025009194557, 2.1147480691430673, 2.206693637366679, 2.2986392055902907, 2.3905847738139023, 2.4825303420375135, 2.574475910261125, 2.666421478484737, 2.7583670467083485, 2.85031261493196, 2.942258183155572, 3.0342037513791835, 3.126149319602795, 3.218094887826407, 3.3100404560500185, 3.40198602427363, 3.4939315924972414, 3.585877160720853, 3.6778227289444647, 3.7697682971680764, 3.861713865391688, 3.9536594336152997, 4.045605001838911, 4.137550570062523, 4.229496138286135, 4.321441706509746, 4.413387274 ...

# %%
abs_del = __Abs[:27]
frq_del = __FS[:27]
phs_del = __Ph[:27]

# %%
x = abs_del[0]*np.cos(2*np.pi*frq_del[0]*(t - phs_del[0]))

for i in range(1,len(abs_del)):
    x += abs_del[i]*np.cos(2*np.pi*frq_del[i]*(t - phs_del[i]))

# %%
fig = go.Figure()
fig.add_scatter(y = x_acc, mode='lines', name='Sum squares')
fig.add_scatter(y = x_acc - x, mode='lines', name='New')
fig.add_scatter(y = x, mode='lines', name='x')
fig.show()
# Out:
# <div>                            <div id="5a7fa6a0-6716-4045-af44-fcb2d4f3c08d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5
# %%
def HankelMatrix(X, L):  
    N = X.shape[0]
    return scipy.linalg.hankel(X[ : N - L + 1], X[N - L : N])

# %%
X = HankelMatrix(x_acc - x,750)

# %%
pca = PCA(n_components=2)
X_PCA = pca.fit_transform(X)
X_PCA = X_PCA/X_PCA.std(axis=0)/10
plt.plot(X_PCA[:,0],X_PCA[:,1]);

# %%
def Trigonometric_series(w):
    
    w = w.reshape((int(len(w)/2),2))*20
    
    phi = np.linspace(0,2*np.pi,1000)
    
    x_ph = np.zeros(1000)+0j

    for k in range(len(x_ph)):    
        ans = 0 
        for i in range(len(w)):
            ans += w[i,0]*np.sin(i*phi[k]) + w[i,1]*np.cos(i*phi[k])*1j
        x_ph[k] = ans
        
    x_ph = x_ph.reshape((len(x_ph),1))

    x_ph = np.concatenate((np.real(x_ph), np.imag(x_ph)), axis=1)
    
    return x_ph

# %%
plt.plot(X_PCA[:,0],X_PCA[:,1])
x_tr = Trigonometric_series(np.array([0.,0.,.009,.009,0.,0.]))
plt.plot(x_tr[:,0],x_tr[:,1])
plt.show()

# %%
def Loss(w):
    x_ph = Trigonometric_series(w)
    nn = NearestNeighbors(n_neighbors = 12, p = 2).fit(X_PCA)
    dists, idxs = nn.kneighbors(x_ph)
    return np.sum(dists)

def Loss_sp(w):
    x_ph = Trigonometric_series(w)
    x_ph_sph = TrajectoryToSpherical(x_ph)
    nn = NearestNeighbors(n_neighbors = 12,p = 1).fit(X_PCA_sph)
    dists, idxs = nn.kneighbors(x_ph_sph)
    return np.sum(dists)

# %%
w0 = np.array([0.,0.,.009,.009,0.,0.])

pca = PCA(n_components=2)
X_PCA = pca.fit_transform(X)
X_PCA = X_PCA/X_PCA.std(axis=0)/10

X_PCA_sph = TrajectoryToSpherical(X_PCA)

for _iter in range(1,250,50):
    fig, axs = plt.subplots(1, 2, figsize = (10,5))
    
    
    res = minimize(Loss, w0,
                   method='nelder-mead',
                   options={'xtol': 1e-3, 'disp': True, 'maxiter': _iter})
    
    x_tr = Trigonometric_series(res.x)

    nn = NearestNeighbors(n_neighbors = 100, p = 2).fit(X_PCA)
    dists, idxs = nn.kneighbors(x_tr)
    
    axs[0].plot(X_PCA[idxs[0],0],X_PCA[idxs[0],1],'o')
    axs[0].plot(x_tr[0,0],x_tr[0,1],'o')
    axs[0].set_ylim(0.1,0.2)
    
    ####################################################################################################
    res_pf = minimize(Loss_sp, w0,
                       method='nelder-mead',
                       options={'xtol': 1e-3, 'disp': True, 'maxiter': _iter})
    
    x_tr = Trigonometric_series(res_pf.x)
    x_tr_sp = TrajectoryToSpherical(x_tr)

    nn = NearestNeighbors(n_neighbors = 100, p = 1).fit(X_PCA_sph)
    dists, idxs = nn.kneighbors(x_tr_sp)
    
    axs[1].plot(X_PCA[idxs[0],0],X_PCA[idxs[0],1],'o')
    axs[1].plot(x_tr[0,0],x_tr[0,1],'o')
    axs[1].set_xlim(-0.04,0.04)
    axs[1].set_ylim(0.1,0.2)
    
    plt.show()
# Out:
# Warning: Maximum number of iterations has been exceeded.
# Warning: Maximum number of iterations has been exceeded.
# Warning: Maximum number of iterations has been exceeded.
# Warning: Maximum number of iterations has been exceeded.
# Warning: Maximum number of iterations has been exceeded.
# Warning: Maximum number of iterations has been exceeded.
# Warning: Maximum number of iterations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 152.660105
#          Iterations: 149
#          Function evaluations: 250
# Warning: Maximum number of iterations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 152.660105
#          Iterations: 149
#          Function evaluations: 250

# %%
plt.figure(figsize=(10,10))
plt.plot(X_PCA[:,0],X_PCA[:,1],alpha = 0.5)

x_tr = Trigonometric_series(res.x)
plt.plot(x_tr[:,0],x_tr[:,1],'r',label = 'Cart',linewidth = 5)

x_tr = Trigonometric_series(res_pf.x)
plt.plot(x_tr[:,0],x_tr[:,1],'g',label = 'Sph',linewidth = 5)

plt.legend()
plt.show()

# %%
fig = go.Figure()

fig.update_layout( autosize=False, width=800, height=800)

fig.add_scatter(x = X_PCA[:,0],y = X_PCA[:,1], mode='lines', name='X_PCA',opacity=0.5)

x_tr = Trigonometric_series(res.x)
fig.add_scatter(x = x_tr[:,0],y = x_tr[:,1], mode='lines', name='Cart')

x_tr = Trigonometric_series(res_pf.x)
fig.add_scatter(x = x_tr[:,0],y = x_tr[:,1], mode='lines', name='Sph')

fig.show()
# Out:
# <div>                            <div id="aab5404b-2d30-4277-a833-46670e1e8a9c" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aab5404b-2d30-4277-a833-46670e1e8a9c")) {                    Plotly.newPlot(                        "aab5404b-2d30-4277-a833-46670e1e8a9c",                        [{"mode": "lines", "name": "X_PCA", "opacity": 0.5, "type": "scatter", "x": [0.15394629115788155, 0.15580311507473033, 0.15754748515509992, 0.15917506191746383, 0.16068361292175976, 0.16207063742870242, 0.1633310703766295, 0.16446672023553738, 0.16546738802361702, 0.1663324200333054, 0.16706706264185245, 0.16766197510740743, 0.1681087024983371, 0.168425963540696, 0.16861062983756175, 0.16866237365192632, 0.1685836270960749, 0.1683736108844563, 0.16803388675592745, 0.16756240195969713, 0.1669589429511469, 0.1662253583078433, 0.16535245582488184, 0.16435220687518365, 0.16322298534304797, 0.16196252410036, 0.16057133811941743, 0.15905185289333118, 0.15740156385203452, 0.15562602423391264, 0.15371962359085653, 0.15168098130365248, 0.14949626984621925, 0.14718749657531643, 0.1447574718375201, 0.1422047444808507, 0.13951874294385685, 0.13670698029514516, 0.13377781691511376, 0.13072718721861423, 0.12757135484306, 0.12430597918444863, 0.12092437633421076, 0.11745568669081366, 0.11389629049749399, 0.11024558430125683, 0.10650744969606832, 0.10268323883815236, 0.0987819423961945, 0.09480586285504795, 0